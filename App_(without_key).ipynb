# %%
# !pip install flask-ngrok
# !pip install pyngrok

# %%
# !pip install Flask

# %%
# !ngrok config add-authtoken      # Вставить сюда ключ для авторизации

# %%
# the main fail for creating html

# folium library
import folium

# create a map in our center
map = folium.Map(location=[57, 44], zoom_start=5)


# create marker for Vladimir
folium.Marker(location=[56.2, 39.8],
      popup=folium.Popup(
          '<img src="https://sun1-97.userapi.com/impg/i7kEmrCzD0JWYeYsZRnPY4WlCcmb4J1-HQ-Clg/Ogi6QqsWiyw.jpg?size=2560x1182&quality=95&sign=3e21547988d99b4ec280ed5ecd3d3df9&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Владимирская область",
      icon=folium.Icon(color='green', icon='tint')
      ).add_to(map)

folium.Marker(location=[55.9, 41.6],
      popup=folium.Popup(
          '<img src="https://sun9-9.userapi.com/impg/5TlWL-HeimGzHCt01cOma-eD0oAJcdiOacioJw/xeMUNe55Fe0.jpg?size=1280x591&quality=95&sign=9f4075ed177749bc43c94e37e6bc107c&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Владимирская область",
      icon=folium.Icon(color='green', icon='tint')
      ).add_to(map)

# create marker for Tula
folium.Marker(location=[53.9, 36.7],
      popup=folium.Popup(
          '<img src="https://sun9-47.userapi.com/impg/0RWyzwLsxFHpYGy62EnutsPlbju5zBq2_BcpKw/rKum7qtPbhY.jpg?size=2560x1182&quality=95&sign=0956cd979298e9ebdeab70b364445cb7&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Тульская область",
      icon=folium.Icon(color='blue', icon='adjust')
      ).add_to(map)

folium.Marker(location=[53.7, 38.3],
      popup=folium.Popup(
          '<img src="https://sun9-70.userapi.com/impg/TJvfDtW69PxS7bn3FPClbPyfPiEE9ER9SuD2Wg/iz-B7SUoi24.jpg?size=2560x1182&quality=95&sign=2782bf9cacc6c81754f1935e8abf3694&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Тульская область",
      icon=folium.Icon(color='blue', icon='adjust')
      ).add_to(map)


# create marker for Kirov
folium.Marker(location=[58.3, 47.6],
      popup=folium.Popup(
          '<img src="https://sun9-63.userapi.com/impg/9Omo86T0L-XrZ7R2FRPbqIhy6lbwCnIcQyr4aw/U4TWGGuObLI.jpg?size=2560x1182&quality=95&sign=2b90a2801ae8f1051ca13668bed35f17&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Кировская область",
      icon=folium.Icon(color='red', icon='adjust')
      ).add_to(map)

folium.Marker(location=[58.7, 52.2],
      popup=folium.Popup(
          '<img src="https://sun9-79.userapi.com/impg/xt7GTPnCOt6lSSg-Ny32ynn7u5fVGBVux8BxJw/MnNNHJ8C3Ss.jpg?size=2560x1182&quality=95&sign=f1e439dba667aadd6463eea2dbe83b3c&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Кировская область",
      icon=folium.Icon(color='red', icon='adjust')
      ).add_to(map)


# create marker for Kaluga
folium.Marker(location=[54.1, 34.3],
      popup=folium.Popup(
          '<img src="https://sun9-20.userapi.com/impg/KAbOjcMIpWhn2dcQv6Y4XhDUOtr8wEIn_uOjrw/orOqSJG3vfo.jpg?size=2560x1182&quality=95&sign=c0b7991fc538eb4cc23f9764faad38c7&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Калужская область",
      icon=folium.Icon(color='orange', icon='tint')
      ).add_to(map)

folium.Marker(location=[54.7, 36.5],
      popup=folium.Popup(
          '<img src="https://sun9-43.userapi.com/impg/QJO--6VtdmAILe47mHvD-K5ah2B4H6QgZyE9zg/ThjY-vUeh-Y.jpg?size=2560x1182&quality=95&sign=89d090b07479228d856521c8869a54c7&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Калужская область",
      icon=folium.Icon(color='orange', icon='tint')
      ).add_to(map)


# create marker for Ryazan
folium.Marker(location=[53.9, 39.6],
      popup=folium.Popup(
          '<img src="https://sun9-52.userapi.com/impg/yRTdk9H8w96YBwhNbBKPHDTui7ZTHDj38I-EmQ/ALVjc9AGCxc.jpg?size=2560x1182&quality=95&sign=a86f2b9ebbc698cd4667d2dcca1f4776&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Рязанская область",
      icon=folium.Icon(color='darkred', icon='certificate')
      ).add_to(map)

folium.Marker(location=[54.3, 41.4],
      popup=folium.Popup(
          '<img src="https://sun9-55.userapi.com/impg/2sTOgPdPk8r-FlfG91qXJggrJqBm0Zxk1i0Sqg/zwIsupBC4Nw.jpg?size=2560x1182&quality=95&sign=ce1ef9e205cea32c90a0182170f293f0&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Рязанская область",
      icon=folium.Icon(color='darkred', icon='certificate')
      ).add_to(map)


# create marker for Udmurtia
folium.Marker(location=[57.7, 53.0],
      popup=folium.Popup(
          '<img src="https://sun9-3.userapi.com/impg/sjwW401zg_2NI-uVV0Z8gZePApT8T09U-2JhpQ/kGCX3BWC1-g.jpg?size=2560x1182&quality=95&sign=b5cced430a9588768292490523d6c739&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Удмуртская республика",
      icon=folium.Icon(color='purple', icon='map-marker')
      ).add_to(map)

folium.Marker(location=[57.0, 52.4],
      popup=folium.Popup(
          '<img src="https://sun9-76.userapi.com/impg/5GDBabyLZ5pbaEJTkJF2vjeXoHvGnAgqVI4WPw/z9Mhi1cU5Ac.jpg?size=2560x1182&quality=95&sign=646cee5d8306373735e9263dd156258a&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Удмуртская республика",
      icon=folium.Icon(color='purple', icon='map-marker')
      ).add_to(map)



# create marker for Marie El
folium.Marker(location=[56.6, 46.9],
      popup=folium.Popup(
          '<img src="https://sun9-18.userapi.com/impg/CfA6LDGo_Fg9Gm5u0G6C0Q5MmHRnUM4fEGai1Q/EdLF-l1kz08.jpg?size=2560x1182&quality=95&sign=b07fd1c3772a93e55b8d9b59510c2e82&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Республика Мари Эл",
      icon=folium.Icon(color='darkgreen', icon='certificate')
      ).add_to(map)

folium.Marker(location=[56.5, 49.0],
      popup=folium.Popup(
          '<img src="https://sun9-80.userapi.com/impg/Tif4BVSUj5PQbOsoqVtXzswThIQaQmd84Xmlwg/GqtuRY7QqLk.jpg?size=2560x1182&quality=95&sign=b9af58d6fc0c9873a54e85b878bb8570&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Республика Мари Эл",
      icon=folium.Icon(color='darkgreen', icon='certificate')
      ).add_to(map)



# create marker for Ivanovo
folium.Marker(location=[56.8, 40.5],
      popup=folium.Popup(
          '<img src="https://sun9-79.userapi.com/impg/IZGPubfeeKjCqOMb2UM_A1m4kVUFPCbBI51lkg/-7b8m96H0qE.jpg?size=2560x1182&quality=95&sign=d6455e49041a6aac8cbe615508701147&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Ивановская область",
      icon=folium.Icon(color='lightgray', icon='certificate')
      ).add_to(map)

folium.Marker(location=[57.0, 42.5],
      popup=folium.Popup(
          '<img src="https://sun9-59.userapi.com/impg/uuarjN4z3xsd4ppBTtzV3MApNkCv4AwNdapY_A/A9egrsq5qIU.jpg?size=2560x1182&quality=95&sign=27c1340c34b3e039f827fecc24378fc8&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Ивановская область",
      icon=folium.Icon(color='lightgray', icon='certificate')
      ).add_to(map)


# create marker for Nizhny Novgorod region
folium.Marker(location=[57.3, 45.2],
      popup=folium.Popup(
          '<img src="https://sun9-25.userapi.com/impg/wnhzLzqbkH7yDCdaqcjTlgZAJhuKTStpwIwiAA/LPeuXLuBJ0M.jpg?size=2560x1182&quality=95&sign=32a98bdc026830b6458109d72019ecad&type=album" alt="Все причины" width="550" height="300">',
          max_width=570),
      tooltip="Нижегородская область",
      icon=folium.Icon(color='cadetblue', icon='map-marker')
      ).add_to(map)

folium.Marker(location=[55.2, 44.3],
      popup=folium.Popup(
          '<img src="https://sun9-30.userapi.com/impg/NFL8-hqhr1WaOl5pEOxnoiIlM6PmhHjyGGDflg/Y4viDTAdZe4.jpg?size=2560x1182&quality=95&sign=55ee87897eeebdd4486defcf4594aad0&type=album" alt="Аварийность по ветру" width="550" height="300">',
          max_width=570),
      tooltip="Нижегородская область",
      icon=folium.Icon(color='cadetblue', icon='map-marker')
      ).add_to(map)

# Save in html
map.save('templates/output.html')

# %%
from pyngrok import ngrok
from flask import Flask
import flask
from flask import render_template

auth = 'Your ker for authorization'
# auth = 'Вставить сюда ключ для авторизации'
port_no = 5000

ngrok.set_auth_token(auth)
public_url = ngrok.connect(5000).public_url
app = flask.Flask(__name__, template_folder = 'templates')

@app.route('/')
def main():
    return render_template('output.html')

print(f" Приложение по ссылке :  {public_url}")  
app.run(port = port_no)
# Out:
#  Приложение по ссылке :  http://3646-35-233-203-217.ngrok.io
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [01/Apr/2023 13:21:23] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Apr/2023 13:21:35] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Apr/2023 13:21:38] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [01/Apr/2023 13:21:42] "GET /favicon.ico HTTP/1.1" 404 -

# %%
ngrok.kill()
